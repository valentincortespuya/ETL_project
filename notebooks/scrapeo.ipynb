# %%
import pandas as pd
import numpy as np
import re
import pickle
from tqdm import tqdm

import time

import random 


from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options



import warnings
warnings.filterwarnings('ignore')
import requests
from bs4 import BeautifulSoup
# !pip install html5lib

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# sacamos los datos de las notas de selectividad de artes y humanidades

# %%
url = "https://www.um.es/web/siu/servicios/evolucion-de-las-notas-de-corte/artes-y-humanidades"

# %%
res1 = requests.get(url)
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, "html.parser")
elemento = soup.select_one("#portlet_com_liferay_journal_content_web_portlet_JournalContentPortlet_INSTANCE_NcSaLy7UYnCZ > div > div:nth-child(2) > div > div > div > div > table")

# %%
tabla = pd.read_html(str(elemento))

# %%
datos = tabla[0]

# %%
df_selec_art_hum = tabla[0]

# %%
df_selec_art_hum
# Out:
#                         Artes y Humanidades            2011/12  \
#                         Artes y Humanidades Unnamed: 1_level_1
# 0                              Bellas Artes          8,994 (S)
# 1         Ciencia y  Tecnología  Geográfica                NaN
# 2                       Estudios  Franceses          7,250 (S)
# 3                        Estudios  Ingleses          6,759 (J)
# 4                        Filología  Clásica          6,590 (J)
# 5                                 Filosofía          5,005 (S)
# 6   Geografía y  Ordenación del  Territorio          6,421 (S)
# 7                                  Historia          8,464 (S)
# 8                        Historia  del Arte          7,103 (S)
# 9            Lengua y  Literatura  Española          7,913 (S)
# 10         Traducción e  Interpretación (F)          6,310 (J)
# 11         Traducción e  Interpretación (I)          6,310 (J)
#
#               2012/13            2013/14            2014/15  \
# ...

# %%
df_selec_art_hum.columns
# Out:
# MultiIndex([('Artes y Humanidades', 'Artes y Humanidades'),
#             (            '2011/12',  'Unnamed: 1_level_1'),
#             (            '2012/13',  'Unnamed: 2_level_1'),
#             (            '2013/14',  'Unnamed: 3_level_1'),
#             (            '2014/15',  'Unnamed: 4_level_1'),
#             (            '2015/16',  'Unnamed: 5_level_1'),
#             (            '2016/17',  'Unnamed: 6_level_1'),
#             (            '2017/18',  'Unnamed: 7_level_1'),
#             (            '2018/19',  'Unnamed: 8_level_1'),
#             (            '2019/20',  'Unnamed: 9_level_1'),
#             (            '2020/21', 'Unnamed: 10_level_1'),
#             (            '2021/22', 'Unnamed: 11_level_1'),
#             (            '2022/23', 'Unnamed: 12_level_1')],
#            )

# %%
df_selec_art_hum
# Out:
#                         Artes y Humanidades            2011/12  \
#                         Artes y Humanidades Unnamed: 1_level_1
# 0                              Bellas Artes          8,994 (S)
# 1         Ciencia y  Tecnología  Geográfica                NaN
# 2                       Estudios  Franceses          7,250 (S)
# 3                        Estudios  Ingleses          6,759 (J)
# 4                        Filología  Clásica          6,590 (J)
# 5                                 Filosofía          5,005 (S)
# 6   Geografía y  Ordenación del  Territorio          6,421 (S)
# 7                                  Historia          8,464 (S)
# 8                        Historia  del Arte          7,103 (S)
# 9            Lengua y  Literatura  Española          7,913 (S)
# 10         Traducción e  Interpretación (F)          6,310 (J)
# 11         Traducción e  Interpretación (I)          6,310 (J)
#
#               2012/13            2013/14            2014/15  \
# ...

# %%
df_selec_art_hum.columns[0]
# Out:
# ('Artes y Humanidades', 'Artes y Humanidades')

# %%
# sacamos los datos de las notas de selectividad de ciencias

# %%
url = "https://www.um.es/web/siu/servicios/evolucion-de-las-notas-de-corte/ciencias"

# %%
res1 = requests.get(url)
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, "html.parser")
elemento2 = soup.select_one("#portlet_com_liferay_journal_content_web_portlet_JournalContentPortlet_INSTANCE_6VzLdSzaP1yd > div > div.portlet-content-container > div > div > div > div > table")

# %%
tabla2 = pd.read_html(str(elemento2))

# %%
datos2 = tabla2[0]

# %%
df_selec_ciencias = tabla2[0]

# %%
df_selec_ciencias
# Out:
#                                      Ciencias            2011/12  \
#                                      Ciencias Unnamed: 1_level_1
# 0                                    Biología          5,785 (J)
# 1                                  Bioquímica          8,574 (J)
# 2                               Biotecnología         10,392 (J)
# 3       Ciencia y Tecnología de los Alimentos          6,640 (S)
# 4                        Ciencias Ambientales          6,316 (S)
# 5                                      Física          5,284 (S)
# 6                                 Matemáticas          5,534 (S)
# 7                                     Química          5,326 (S)
# 8   PCEO Matemáticas e Ingeniería Informática          5,904 (S)
# 9                   PCEO Matemáticas y Física                NaN
# 10          PCEO Química e Ingeniería Química                NaN
#
#               2012/13            2013/14            2014/15  \
# ...

# %%
# sacamos los datos de las notas de selectividad de ciencias de la salud

# %%
url = "https://www.um.es/web/siu/servicios/evolucion-de-las-notas-de-corte/ciencias-de-la-salud"

# %%
res1 = requests.get(url)
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, "html.parser")
elemento3 = soup.select_one("#portlet_com_liferay_journal_content_web_portlet_JournalContentPortlet_INSTANCE_y3jCI0gBL2AD > div > div.portlet-content-container > div > div > div > div > table")

# %%
tabla3 = pd.read_html(str(elemento3))

# %%
datos3 = tabla3[0]

# %%
df_selec_ciencias_salud = tabla3[0]

# %%
df_selec_ciencias_salud
# Out:
#             Ciencias de la Salud            2011/12            2012/13  \
#             Ciencias de la Salud Unnamed: 1_level_1 Unnamed: 2_level_1
# 0           Enfermería Cartagena          8,576 (J)           9,45 (J)
# 1              Enfermería Murcia          9,637 (J)         10,060 (J)
# 2               Enfermería Lorca          8,500 (J)           9,29 (J)
# 3                       Farmacia          8,213 (J)          9,363 (J)
# 4                   Fisioterapia          8,297 (J)          9,158 (J)
# 5                      Logopedia          7,815 (S)          6,333 (S)
# 6                       Medicina         11,987 (J)         12,290 (J)
# 7   Nutrición Humana y Dietética          5,070 (S)           5,75 (S)
# 8                    Odontología         10,821 (J)         11,524 (J)
# 9            Óptica y Optometría          5,402 (S)           5,05 (S)
# 10                    Psicología          6,955 (J)           6,57 (J)
# ...

# %%
# sacamos los datos de las notas de selectividad de ciencias sociales y juridicas

# %%
url = "https://www.um.es/web/siu/servicios/evolucion-de-las-notas-de-corte/ciencias-sociales-y-juridicas"

# %%
res1 = requests.get(url)
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, "html.parser")
elemento4 = soup.select_one("#portlet_com_liferay_journal_content_web_portlet_JournalContentPortlet_INSTANCE_zX1PLiD4cz1R > div > div.portlet-content-container > div > div > div > div > table")

# %%
tabla4 = pd.read_html(str(elemento4))

# %%
datos4 = tabla4[0]

# %%
df_selec_ciencias_sociales = tabla4[0]

# %%
df_selec_ciencias_sociales
# Out:
#                         Ciencias Sociales y Jurídicas            2011/12  \
#                         Ciencias Sociales y Jurídicas Unnamed: 1_level_1
# 0                                              A.D.E.          5,460 (S)
# 1                  Ciencia Política y Gestión Publica          6,089 (S)
# 2       Ciencias de la Actividad Física y del Deporte          8,811 (J)
# 3   Ciencias Políticas, Gobierno y Administración ...                NaN
# 4                            Comunicación Audiovisual          6,800 (J)
# 5                                        Criminología          8,163 (J)
# 6                                             Derecho          5,996 (J)
# 7                                            Economía          6,247 (S)
# 8                                  Educación Infantil          7,280 (J)
# 9                                  Educación Primaria          7,114 (J)
# 10                            Educación Infantil ISEN                NaN
# ...

# %%
# sacamos los datos de las notas de selectividad de ingenieria y arquitectura

# %%
url = "https://www.um.es/web/siu/servicios/evolucion-de-las-notas-de-corte/ingenieria-y-arquitectura"

# %%
res1 = requests.get(url)
response = requests.get(url)
html_content = response.content

# %%
soup = BeautifulSoup(html_content, "html.parser")
elemento5 = soup.select_one("#portlet_com_liferay_journal_content_web_portlet_JournalContentPortlet_INSTANCE_CG1G7xIJ6a1C > div > div.portlet-content-container > div > div > div > div > table")

# %%
tabla5 = pd.read_html(str(elemento5))

# %%
datos5 = tabla5[0]

# %%
df_selec_ing_arc = tabla5[0]

# %%
df_selec_ing_arc
# Out:
#                    Ingeniería y Arquitectura            2011/12  \
#                    Ingeniería y Arquitectura Unnamed: 1_level_1
# 0              Ciencia e Ingeniería de Datos                NaN
# 1                     Ingeniería Informática          5,242 (S)
# 2                         Ingeniería química          5,437 (S)
# 3  PCEO Matemáticas e Ingeniería Informática          5,904 (S)
#
#              2012/13            2013/14            2014/15            2015/16  \
#   Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                NaN                NaN                NaN                NaN
# 1          5,295 (S)          5,260 (J)          8,670 (S)         11,353 (S)
# 2          6,128 (S)          5,900 (J)          5,474 (J)          8,421 (S)
# 3          7,095 (J)          6,086 (J)              8 (J)          6,164 (J)
#
#              2016/17            2017/18            2018/19            2019/20  \
# ...

# %%
'Ingeniería y Arquitectura' 'Ciencias Sociales y Jurídicas' 'Ciencias de la Salud''Ciencias''Artes y Humanidades'
# Out:
# 'Ingeniería y ArquitecturaCiencias Sociales y JurídicasCiencias de la SaludCienciasArtes y Humanidades'

# %% [markdown]
# # función para hacer iterrows para todos los dt anteriores!!

# %%
import pandas as pd

def procesar_dataframes(lista_dataframes):
    
    datos = []

    
    for df in lista_dataframes:
        
        
        nuevos_nombres = df.columns.get_level_values(0).tolist()

         
        df.columns = nuevos_nombres

        
        
        
        for indice, fila in df.iterrows():
            
            facultad = df.columns[0]

            
            grado = fila[0]

            
            for i in range(1, len(fila), 2):
               
                año = df.columns[i]

                
                valor_selectividad = fila[i]

                
                datos.append([facultad, grado, valor_selectividad, año])

    
    df_nuevo = pd.DataFrame(datos, columns=['facultad', 'grado', 'valor selectividad', 'año'])

    
    return df_nuevo

# %%
lista_dataframes = [df_selec_art_hum, df_selec_ing_arc, df_selec_ciencias_sociales, df_selec_ciencias_salud, df_selec_ciencias]


df_final = procesar_dataframes(lista_dataframes)


df_final
# Out:
#                           facultad  \
# 0              Artes y Humanidades
# 1              Artes y Humanidades
# 2              Artes y Humanidades
# 3              Artes y Humanidades
# 4              Artes y Humanidades
# 5              Artes y Humanidades
# 6              Artes y Humanidades
# 7              Artes y Humanidades
# 8              Artes y Humanidades
# 9              Artes y Humanidades
# 10             Artes y Humanidades
# 11             Artes y Humanidades
# 12             Artes y Humanidades
# 13             Artes y Humanidades
# 14             Artes y Humanidades
# 15             Artes y Humanidades
# 16             Artes y Humanidades
# 17             Artes y Humanidades
# 18             Artes y Humanidades
# 19             Artes y Humanidades
# 20             Artes y Humanidades
# 21             Artes y Humanidades
# 22             Artes y Humanidades
# 23             Artes y Humanidades
# 24             Artes y Humanidades
# ...

# %%
df_final['valor selectividad'] = df_final['valor selectividad'].astype(str)
df_final['valor selectividad'] = df_final['valor selectividad'].apply(lambda x: re.sub(r'\(.*?\)|\*', '', x))
df_final['valor selectividad'] = df_final['valor selectividad'].str.replace(',', '.')
df_final['año'] = df_final['año'].str.replace('/', '-20')


df_final
# Out:
#                           facultad  \
# 0              Artes y Humanidades
# 1              Artes y Humanidades
# 2              Artes y Humanidades
# 3              Artes y Humanidades
# 4              Artes y Humanidades
# 5              Artes y Humanidades
# 6              Artes y Humanidades
# 7              Artes y Humanidades
# 8              Artes y Humanidades
# 9              Artes y Humanidades
# 10             Artes y Humanidades
# 11             Artes y Humanidades
# 12             Artes y Humanidades
# 13             Artes y Humanidades
# 14             Artes y Humanidades
# 15             Artes y Humanidades
# 16             Artes y Humanidades
# 17             Artes y Humanidades
# 18             Artes y Humanidades
# 19             Artes y Humanidades
# 20             Artes y Humanidades
# 21             Artes y Humanidades
# 22             Artes y Humanidades
# 23             Artes y Humanidades
# 24             Artes y Humanidades
# ...

# %%
dt_selectividad_murcia = df_final.copy()

dt_selectividad_murcia.to_csv("../DATA/selectividad/dt_selectividad_murcia.csv", index=False)
