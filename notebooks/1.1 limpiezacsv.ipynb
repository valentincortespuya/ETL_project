# %%
import pandas as pd
from collections import Counter
import pickle
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# importo el csv donde tengo todos los datos de matriculados en universidades
df_matriculas = pd.read_csv('2_2_NI_Sex_Nac_Rama_CAsc.csv',sep=';')
df_matriculas.head(100
                )
# Out:
#                        Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2  \
# 0   Estudiantes de nuevo ingreso en Grado por tipo...        NaN        NaN
# 1                      Unidades: Nmero de estudiantes        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN      Total        NaN
# 4                                                 NaN  2015-2016  2016-2017
# 5                                               Total        NaN        NaN
# 6                                               Total        NaN        NaN
# 7                                               Total        NaN        NaN
# 8                                         Ambos sexos        NaN        NaN
# 9                                               Total   345835.0   340988.0
# 10                                       Espa񡻳27316.0   321491.0   316101.0
# ...

# %%
#vamos a limpiar esto un poco. de momento vamos a quitar filas que no son necesarias. como solo voy a trabajar con los datos totales, voy a descartar todos los datos por comunidades autonomas. 
#voy a buscar Andalucía (Andaluc_) y borrar todo lo que venga despues

hasta_aqui = df_matriculas[df_matriculas['Resultados por comunidad aut󮯭a'] == 'Andaluc_'].index[0]

# %%
df_matriculas = df_matriculas.loc[:hasta_aqui]
df_matriculas
# Out:
#                         Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2  \
# 0    Estudiantes de nuevo ingreso en Grado por tipo...        NaN        NaN
# 1                       Unidades: Nmero de estudiantes        NaN        NaN
# 2                                                  NaN        NaN        NaN
# 3                                                  NaN      Total        NaN
# 4                                                  NaN  2015-2016  2016-2017
# 5                                                Total        NaN        NaN
# 6                                                Total        NaN        NaN
# 7                                                Total        NaN        NaN
# 8                                          Ambos sexos        NaN        NaN
# 9                                                Total   345835.0   340988.0
# 10                                        Espa񡻳27316.0   321491.0   316101.0
# ...

# %%
#la fila 0 1 2 , no me vale de nada. 
df_matriculas = df_matriculas.drop([0, 1, 2])
df_matriculas
# Out:
#             Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 3                                      NaN      Total        NaN        NaN
# 4                                      NaN  2015-2016  2016-2017  2017-2018
# 5                                    Total        NaN        NaN        NaN
# 6                                    Total        NaN        NaN        NaN
# 7                                    Total        NaN        NaN        NaN
# 8                              Ambos sexos        NaN        NaN        NaN
# 9                                    Total   345835.0   340988.0   337105.0
# 10                            Espa񡻳27316.0   321491.0   316101.0   314595.0
# 11                              Uni󮠅uropea     7810.0     8527.0     8783.0
# 12                         Resto de Europa     1568.0     1628.0     1707.0
# 13                       EEUU y Canadự93.0      181.0      269.0      311.0
# ...

# %%
#ahora voy a quedarme solo con los datos totales. creando una dt diferente para cada area de conocimiento.

# %%
datos_areas =df_matriculas.columns[df_matriculas.columns.get_loc("Unnamed: 8"):]

# %%
df_datos_areas=df_matriculas[datos_areas].copy()
df_datos_areas
# Out:
#                       Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 3    Ciencias Sociales y Jur_cas        NaN         NaN         NaN
# 4                      2015-2016  2016-2017   2017-2018   2018-2019
# 5                            NaN        NaN         NaN         NaN
# 6                            NaN        NaN         NaN         NaN
# 7                            NaN        NaN         NaN         NaN
# 8                            NaN        NaN         NaN         NaN
# 9                       164376.0   162124.0    162676.0    157764.0
# 10                      153527.0   153156.0    147654.0    148875.0
# 11                        2870.0     3151.0      3421.0      3519.0
# 12                         798.0      811.0       860.0       802.0
# 13                          89.0      120.0       175.0       202.0
# 14                        2546.0     2515.0      2887.0      3287.0
# 15                         572.0      715.0       701.0       782.0
# ...

# %%
datos_totales =df_matriculas.columns[:df_matriculas.columns.get_loc("Unnamed: 8")]
df_datos_totales=df_matriculas[datos_totales].copy()
df_datos_totales
# Out:
#             Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 3                                      NaN      Total        NaN        NaN
# 4                                      NaN  2015-2016  2016-2017  2017-2018
# 5                                    Total        NaN        NaN        NaN
# 6                                    Total        NaN        NaN        NaN
# 7                                    Total        NaN        NaN        NaN
# 8                              Ambos sexos        NaN        NaN        NaN
# 9                                    Total   345835.0   340988.0   337105.0
# 10                            Espa񡻳27316.0   321491.0   316101.0   314595.0
# 11                              Uni󮠅uropea     7810.0     8527.0     8783.0
# 12                         Resto de Europa     1568.0     1628.0     1707.0
# 13                       EEUU y Canadự93.0      181.0      269.0      311.0
# ...

# %%
#seguimos de limpieza, vamos a quitar los nan y hacer que los años sean las columnas

# %%
#ponemos el indice nuevo
df_datos_totales = df_datos_totales.reset_index(drop=True)

# %%
df_datos_totales
# Out:
#             Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                      NaN      Total        NaN        NaN
# 1                                      NaN  2015-2016  2016-2017  2017-2018
# 2                                    Total        NaN        NaN        NaN
# 3                                    Total        NaN        NaN        NaN
# 4                                    Total        NaN        NaN        NaN
# 5                              Ambos sexos        NaN        NaN        NaN
# 6                                    Total   345835.0   340988.0   337105.0
# 7                             Espa񡻳27316.0   321491.0   316101.0   314595.0
# 8                               Uni󮠅uropea     7810.0     8527.0     8783.0
# 9                          Resto de Europa     1568.0     1628.0     1707.0
# 10                       EEUU y Canadự93.0      181.0      269.0      311.0
# ...

# %%
df_datos_totales= df_datos_totales.drop([0, 2, 3, 4]) #me quito las columnas que no tienen nada

# %%
df_datos_totales=df_datos_totales.reset_index(drop=True)

# %%
df_datos_totales = df_datos_totales.fillna("-") #me quito los NaN

# %%
df_datos_totales
# Out:
#             Resultados por comunidad aut󮯭a Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                        -  2015-2016  2016-2017  2017-2018
# 1                              Ambos sexos          -          -          -
# 2                                    Total   345835.0   340988.0   337105.0
# 3                             Espa񡻳27316.0   321491.0   316101.0   314595.0
# 4                               Uni󮠅uropea     7810.0     8527.0     8783.0
# 5                          Resto de Europa     1568.0     1628.0     1707.0
# 6                        EEUU y Canadự93.0      181.0      269.0      311.0
# 7                    Am鲩ca Latina y Caribe     4959.0     4943.0     5686.0
# 8                           Norte de frica     1490.0     1682.0     1680.0
# 9                           Resto de frica      445.0      473.0      558.0
# 10                     Asia y Ocean_2054.0     2063.0     2321.0     2497.0
# ...

# %%
df_datos_totales.iloc[1]
# Out:
# Resultados por comunidad aut󮯭a                Ambos sexos
# Unnamed: 1                                              -
# Unnamed: 2                                              -
# Unnamed: 3                                              -
# Unnamed: 4                                              -
# Unnamed: 5                                              -
# Unnamed: 6                                              -
# Unnamed: 7                                              -
# Name: 1, dtype: object

# %%
df_datos_totales.iloc[1,0] = "objetos"

# %%
df_datos_totales.iloc[1][0]
# Out:
# 'objetos'

# %%
nuevas_col = [i for i in df_datos_totales.iloc[1]]

# %%
df_datos_totales.columns = nuevas_col
df_datos_totales
# Out:
#                                    objetos          -          -          -  \
# 0                                        -  2015-2016  2016-2017  2017-2018
# 1                                  objetos          -          -          -
# 2                                    Total   345835.0   340988.0   337105.0
# 3                             Espa񡻳27316.0   321491.0   316101.0   314595.0
# 4                               Uni󮠅uropea     7810.0     8527.0     8783.0
# 5                          Resto de Europa     1568.0     1628.0     1707.0
# 6                        EEUU y Canadự93.0      181.0      269.0      311.0
# 7                    Am鲩ca Latina y Caribe     4959.0     4943.0     5686.0
# 8                           Norte de frica     1490.0     1682.0     1680.0
# 9                           Resto de frica      445.0      473.0      558.0
# 10                     Asia y Ocean_2054.0     2063.0     2321.0     2497.0
# ...

# %%
df_datos_totales["objetos"]
# Out:
# 0                                          -
# 1                                    objetos
# 2                                      Total
# 3                               Espa񡻳27316.0
# 4                                 Uni󮠅uropea
# 5                            Resto de Europa
# 6                          EEUU y Canadự93.0
# 7                      Am鲩ca Latina y Caribe
# 8                             Norte de frica
# 9                             Resto de frica
# 10                       Asia y Ocean_2054.0
# 11                                   Hombres
# 12                                     Total
# 13                              Espa񡻱50751.0
# 14                                Uni󮠅uropea
# 15                           Resto de Europa
# 16                          EEUU y Canadỷ6.0
# 17                     Am鲩ca Latina y Caribe
# 18                            Norte de frica
# 19                            Resto de frica
# 20                        Asia y Ocean_999.0
# ...

# %%
df_datos_totales['objetos'] = df_datos_totales['objetos'].str.replace(' ', '')

# %%
df_datos_totales["objetos"]
# Out:
# 0                       -
# 1                 objetos
# 2                   Total
# 3            Espa񡻳27316.0
# 4              Uni󮠅uropea
# 5           RestodeEuropa
# 6         EEUUyCanadự93.0
# 7      Am鲩caLatinayCaribe
# 8            Nortedefrica
# 9            Restodefrica
# 10      AsiayOcean_2054.0
# 11                Hombres
# 12                  Total
# 13           Espa񡻱50751.0
# 14             Uni󮠅uropea
# 15          RestodeEuropa
# 16         EEUUyCanadỷ6.0
# 17     Am鲩caLatinayCaribe
# 18           Nortedefrica
# 19           Restodefrica
# 20       AsiayOcean_999.0
# 21                Mujeres
# 22                  Total
# 23           Espa񡻱76565.0
# 24             Uni󮠅uropea
# 25          RestodeEuropa
# 26        EEUUyCanadự17.0
# 27     Am鲩caLatinayCaribe
# 28           Nortedefrica
# 29           Restodefrica
# 30      AsiayOcean_1055.0
# 31             Presencial
# 32             Ambossexos
# 33                  Total
# 34           Espa񡻲60483.0
# ...

# %%
import pandas as pd
import re
df_datos_totales["objetos"] = df_datos_totales["objetos"].apply(lambda x: re.sub('[^a-zA-Z]', '', x))

# %%
df_datos_totales
# Out:
#                objetos          -          -          -          -          -  \
# 0                       2015-2016  2016-2017  2017-2018  2018-2019  2019-2020
# 1              objetos          -          -          -          -          -
# 2                Total   345835.0   340988.0   337105.0   337055.0   341995.0
# 3                 Espa   321491.0   316101.0   314595.0   317414.0   333430.0
# 4            Uniuropea     7810.0     8527.0     8783.0     9242.0     9547.0
# 5        RestodeEuropa     1568.0     1628.0     1707.0     1622.0     1674.0
# 6           EEUUyCanad      181.0      269.0      311.0      330.0      331.0
# 7    AmcaLatinayCaribe     4959.0     4943.0     5686.0     6324.0     7183.0
# 8         Nortedefrica     1490.0     1682.0     1680.0     1914.0     2509.0
# 9         Restodefrica      445.0      473.0      558.0      550.0      605.0
# 10          AsiayOcean     2063.0     2321.0     2497.0     2733.0     2835.0
# ...

# %%
df_datos_totales=df_datos_totales.reset_index(drop=True)

# %%
df_datos_totales
# Out:
#                objetos          -          -          -          -          -  \
# 0                       2015-2016  2016-2017  2017-2018  2018-2019  2019-2020
# 1              objetos          -          -          -          -          -
# 2                Total   345835.0   340988.0   337105.0   337055.0   341995.0
# 3                 Espa   321491.0   316101.0   314595.0   317414.0   333430.0
# 4            Uniuropea     7810.0     8527.0     8783.0     9242.0     9547.0
# 5        RestodeEuropa     1568.0     1628.0     1707.0     1622.0     1674.0
# 6           EEUUyCanad      181.0      269.0      311.0      330.0      331.0
# 7    AmcaLatinayCaribe     4959.0     4943.0     5686.0     6324.0     7183.0
# 8         Nortedefrica     1490.0     1682.0     1680.0     1914.0     2509.0
# 9         Restodefrica      445.0      473.0      558.0      550.0      605.0
# 10          AsiayOcean     2063.0     2321.0     2497.0     2733.0     2835.0
# ...

# %%
df_datos_totales.iat[0, 0] = "objetos"

# %%
df_datos_totales.columns = df_datos_totales.iloc[0]

# %%
df_datos_totales
# Out:
# 0              objetos  2015-2016  2016-2017  2017-2018  2018-2019  2019-2020  \
# 0              objetos  2015-2016  2016-2017  2017-2018  2018-2019  2019-2020
# 1              objetos          -          -          -          -          -
# 2                Total   345835.0   340988.0   337105.0   337055.0   341995.0
# 3                 Espa   321491.0   316101.0   314595.0   317414.0   333430.0
# 4            Uniuropea     7810.0     8527.0     8783.0     9242.0     9547.0
# 5        RestodeEuropa     1568.0     1628.0     1707.0     1622.0     1674.0
# 6           EEUUyCanad      181.0      269.0      311.0      330.0      331.0
# 7    AmcaLatinayCaribe     4959.0     4943.0     5686.0     6324.0     7183.0
# 8         Nortedefrica     1490.0     1682.0     1680.0     1914.0     2509.0
# 9         Restodefrica      445.0      473.0      558.0      550.0      605.0
# 10          AsiayOcean     2063.0     2321.0     2497.0     2733.0     2835.0
# ...

# %%
df_datos_totales = df_datos_totales.drop(0)

# %%
df_datos_totales=df_datos_totales.reset_index(drop=True)

# %%
df_datos_totales = df_datos_totales.drop(0)

# %%
df_datos_totales=df_datos_totales.reset_index(drop=True)

# %%
df_datos_totales
# Out:
# 0              objetos 2015-2016 2016-2017 2017-2018 2018-2019 2019-2020  \
# 0                Total  345835.0  340988.0  337105.0  337055.0  341995.0
# 1                 Espa  321491.0  316101.0  314595.0  317414.0  333430.0
# 2            Uniuropea    7810.0    8527.0    8783.0    9242.0    9547.0
# 3        RestodeEuropa    1568.0    1628.0    1707.0    1622.0    1674.0
# 4           EEUUyCanad     181.0     269.0     311.0     330.0     331.0
# 5    AmcaLatinayCaribe    4959.0    4943.0    5686.0    6324.0    7183.0
# 6         Nortedefrica    1490.0    1682.0    1680.0    1914.0    2509.0
# 7         Restodefrica     445.0     473.0     558.0     550.0     605.0
# 8           AsiayOcean    2063.0    2321.0    2497.0    2733.0    2835.0
# 9              Hombres         -         -         -         -         -
# 10               Total  158403.0  155326.0  150989.0  151707.0  152461.0
# 11                Espa  147185.0  142369.0  142299.0  141984.0  144545.0
# ...

# %%
df_datos_genero = df_datos_totales.iloc[0:29].copy()

# %%
df_datos_genero['genero'] = ''

# %%
df_datos_genero
# Out:
# 0             objetos 2015-2016 2016-2017 2017-2018 2018-2019 2019-2020  \
# 0               Total  345835.0  340988.0  337105.0  337055.0  341995.0
# 1                Espa  321491.0  316101.0  314595.0  317414.0  333430.0
# 2           Uniuropea    7810.0    8527.0    8783.0    9242.0    9547.0
# 3       RestodeEuropa    1568.0    1628.0    1707.0    1622.0    1674.0
# 4          EEUUyCanad     181.0     269.0     311.0     330.0     331.0
# 5   AmcaLatinayCaribe    4959.0    4943.0    5686.0    6324.0    7183.0
# 6        Nortedefrica    1490.0    1682.0    1680.0    1914.0    2509.0
# 7        Restodefrica     445.0     473.0     558.0     550.0     605.0
# 8          AsiayOcean    2063.0    2321.0    2497.0    2733.0    2835.0
# 9             Hombres         -         -         -         -         -
# 10              Total  158403.0  155326.0  150989.0  151707.0  152461.0
# 11               Espa  147185.0  142369.0  142299.0  141984.0  144545.0
# ...

# %%
df_datos_genero['genero'] = ''
df_datos_genero.loc[0:9, 'genero'] = "ambos sexos"
df_datos_genero.loc[10:18, 'genero'] = "hombres"
df_datos_genero.loc[20:, 'genero'] = "mujeres"

# %%
df_datos_genero = df_datos_genero.drop([9, 19])


df_datos_genero = df_datos_genero.reset_index(drop=True)

# %%
df_datos_genero
# Out:
# 0             objetos 2015-2016 2016-2017 2017-2018 2018-2019 2019-2020  \
# 0               Total  345835.0  340988.0  337105.0  337055.0  341995.0
# 1                Espa  321491.0  316101.0  314595.0  317414.0  333430.0
# 2           Uniuropea    7810.0    8527.0    8783.0    9242.0    9547.0
# 3       RestodeEuropa    1568.0    1628.0    1707.0    1622.0    1674.0
# 4          EEUUyCanad     181.0     269.0     311.0     330.0     331.0
# 5   AmcaLatinayCaribe    4959.0    4943.0    5686.0    6324.0    7183.0
# 6        Nortedefrica    1490.0    1682.0    1680.0    1914.0    2509.0
# 7        Restodefrica     445.0     473.0     558.0     550.0     605.0
# 8          AsiayOcean    2063.0    2321.0    2497.0    2733.0    2835.0
# 9                Espa  147185.0  142369.0  142299.0  141984.0  144545.0
# 10          Uniuropea    3115.0    3589.0    3527.0    3770.0    3936.0
# 11      RestodeEuropa     591.0     621.0     630.0     593.0     644.0
# ...
